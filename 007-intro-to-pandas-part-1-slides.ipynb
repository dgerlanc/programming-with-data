# %% [markdown]
# (c) 2016 - Present, Enplus Advisors, Inc.

# %% [markdown]
# # Intro to Pandas - Part I:
# ## A Library for Data Alignment and Computation

# %% [markdown]
# Goals:
#
# * pandas has a huge API
# * Our goal is to distill some wisdom about python

# %% [markdown]
# # Pandas

# %% [markdown]
# Expansive library with a huge API.

# %% [markdown]
# Distill some `pandas` wisdom.

# %% [markdown]
# # Series

# %% [markdown]
# Series is the building block of `pandas`.

# %% [markdown]
# * Ordered key-value pairs with homogeneous data type

# %% [markdown]
# * A data array and a label array

# %% [markdown]
# # Series

# %% [markdown]
# * These are the standard imports we'll assume.
# * Let's create a Series.

# %%
import numpy as np
import pandas as pd

s = pd.Series([6, 8, 7, 5])
s
# Out:
# 0    6
# 1    8
# 2    7
# 3    5
# dtype: int64

# %% [markdown]
# `dtype` is the `Series` datatype. Corresponds to the `numpy` dtype.

# %%
s.astype(np.float64)
# Out:
# 0    6.0
# 1    8.0
# 2    7.0
# 3    5.0
# dtype: float64

# %% [markdown]
# # Series

# %% [markdown]
# A series is:
# A mapping from an `index` --> `values`
#
# Note: Not required to be unique but some operations are not supported
# if there are duplicates, e.g., unstacking

# %% [markdown]
# # Series - Implicit Index

# %%
s = pd.Series([6, 8, 7, 5])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %% [markdown]
# If you don't provide explicit labels you get increasing integer labels.

# %%
s.values
# Out:
# array([6, 8, 7, 5])

# %% [markdown]
# Notice that `s.values` is a `numpy` array

# %% [markdown]
# # Series - Explicit Index

# %%
s1 = pd.Series([6, 8, 7, 5], index=['b', 'd', 'c', 'a'])
s1
# Out:
# b    6
# d    8
# c    7
# a    5
# dtype: int64

# %%
s1.index
# Out:
# Index(['b', 'd', 'c', 'a'], dtype='object')

# %% [markdown]
# Now we have a new kind of `Index`, but the values stay the same.

# %%
s1.values
# Out:
# array([6, 8, 7, 5])

# %% [markdown]
# # Series

# %% [markdown]
# Can also create a series from a `dict`.

# %% [markdown]
# Since `dict`s are unordered, explicitly sorted by the keys which
# become the `index`.

# %%
s2 = pd.Series({'b': 6, 'd': 8, 'c': 7, 'a': 5})
s2
# Out:
# a    5
# b    6
# c    7
# d    8
# dtype: int64

# %% [markdown]
# # Series - Selection

# %% [markdown]
# Selection by integer index, labels, and slices.

# %%
s2[0]
# Out:
# 5

# %%
s2['a']
# Out:
# 5

# %%
s2[['a', 'c']]
# Out:
# a    5
# c    7
# dtype: int64

# %% [markdown]
# # Series - Selection

# %%
s2[0:2]
# Out:
# a    5
# b    6
# dtype: int64

# %% [markdown]
# Note how all of the selection operations preserve the index.

# %% [markdown]
# # Series - Filtering

# %% [markdown]
# All operations are vectorized over the `Series`

# %%
idx = s2 > 5
idx
# Out:
# a    False
# b     True
# c     True
# d     True
# dtype: bool

# %%
# Selecting with a boolean vector
s2[idx]
# Out:
# b    6
# c    7
# d    8
# dtype: int64

# %% [markdown]
# ## Filtering

# %%
idx = (6 < s2) & (s2 < 100)
idx
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %% [markdown]
# `&` binds more tightly than comparison operators so you need parentheses.

# %% [markdown]
# # Filtering - Missing Data

# %% [markdown]
# Pandas has decent support for missing data.

# %%
s3 = pd.Series([6., 8., np.nan, 7.])
s3
# Out:
# 0    6.0
# 1    8.0
# 2    NaN
# 3    7.0
# dtype: float64

# %%
s3.isnull()
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# dtype: bool

# %%
s3[pd.notnull(s3)]
# Out:
# 0    6.0
# 1    8.0
# 3    7.0
# dtype: float64

# %% [markdown]
# Note the preservation of labels (index)

# %% [markdown]
# ## Filtering

# %%
s4 = pd.Series([1, 2, 3, None, 5], index=list('abcde'))

# %% [markdown]
# What is the `dtype` of s4?

# %%
s4
# Out:
# a    1.0
# b    2.0
# c    3.0
# d    NaN
# e    5.0
# dtype: float64

# %% [markdown]
# WARNING: There is no integer NA type in pandas.

# %% [markdown]
# Operations in `pandas` are implicitly aligned by index!

# %%
s2 = pd.Series([6, 8, 7, 5], index=list('abcd'))
s4 = pd.Series([1, 2, 3, None, 5], index=list('abcde'))

s2 + s4
# Out:
# a     7.0
# b    10.0
# c    10.0
# d     NaN
# e     NaN
# dtype: float64

# %% [markdown]
# Performs an outer join, filling missing levels with NAs
